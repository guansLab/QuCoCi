# %%
# !pip install qiskit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting qiskit
#   Using cached qiskit-0.38.0-py3-none-any.whl
# Collecting qiskit-aer==0.11.0
#   Using cached qiskit_aer-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# Collecting qiskit-terra==0.21.2
#   Using cached qiskit_terra-0.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
# Collecting qiskit-ibmq-provider==0.19.2
#   Using cached qiskit_ibmq_provider-0.19.2-py3-none-any.whl (240 kB)
# Requirement already satisfied: numpy>=1.16.3 in /home/neniu/.local/lib/python3.10/site-packages (from qiskit-aer==0.11.0->qiskit) (1.23.2)
# Collecting scipy>=1.0
#   Using cached scipy-1.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/neniu/.local/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.8.2)
# Requirement already satisfied: requests>=2.19 in /usr/lib/python3/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.25.1)
# Collecting websockets>=10.0
#   Using cached websockets-10.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (111 kB)
# Collecting requests-ntlm>=1.1.0
#   Using cached requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: websocket-client>=1.0.1 in /home/neniu/.local/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.4.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/lib/python3/dist-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.26.5)
# Collecting retworkx>=0.11.0
#   Using cached retworkx-0.11.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: psutil>=5 in /home/neniu/.local/lib/python3.10/site-packages (from qiskit-terra==0.21.2->qiskit) (5.9.1)
# Collecting stevedore>=3.0.0
#   Using cached stevedore-4.0.0-py3-none-any.whl (49 kB)
# Collecting symengine>=0.9
#   Using cached symengine-0.9.2-cp310-cp310-manylinux2010_x86_64.whl (37.5 MB)
# Collecting tweedledum<2.0,>=1.1
#   Using cached tweedledum-1.1.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (929 kB)
# Collecting dill>=0.3
#   Using cached dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting sympy>=1.3
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Collecting ply>=3.10
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.16.0)
# Collecting ntlm-auth>=1.0.2
#   Using cached ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: cryptography>=1.3 in /usr/lib/python3/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (3.4.8)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.10.0-py2.py3-none-any.whl (112 kB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.2.1-py3-none-any.whl (532 kB)
# Installing collected packages: ply, mpmath, websockets, tweedledum, sympy, symengine, scipy, retworkx, pbr, ntlm-auth, dill, stevedore, requests-ntlm, qiskit-terra, qiskit-ibmq-provider, qiskit-aer, qiskit
#   WARNING: The script isympy is installed in '/home/neniu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pbr is installed in '/home/neniu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed dill-0.3.5.1 mpmath-1.2.1 ntlm-auth-1.5.0 pbr-5.10.0 ply-3.11 qiskit-0.38.0 qiskit-aer-0.11.0 qiskit-ibmq-provider-0.19.2 qiskit-terra-0.21.2 requests-ntlm-1.1.0 retworkx-0.11.0 scipy-1.9.1 stevedore-4.0.0 symengine-0.9.2 sympy-1.11.1 tweedledum-1.1.1 websockets-10.3

# %%
from qiskit import QuantumCircuit, Aer, transpile

# %%
from qiskit.visualization import plot_bloch_multivector

# %%
import random
theta = random.uniform(0, 3.14)
test = QuantumCircuit(1)
test.h(0)
test.rz(theta, [0])

# %%
print(test)
# Out:
#    ┌───┐┌─────────────┐
# q: ┤ H ├┤ Rz(0.59742) ├
#    └───┘└─────────────┘

# %%
simulator = Aer.get_backend('statevector_simulator')
circ = transpile(test, simulator)
result = simulator.run(circ,shots=10).result()

psi = result.get_statevector(circ)
print(psi)
plot_bloch_multivector(psi)
# Out:
# Statevector([0.67579356-0.20809387j, 0.67579356+0.20809387j],
#             dims=(2,))

# %%
# Out:
# Statevector([0.45740771-0.53923853j, 0.45740771+0.53923853j],
#             dims=(2,))
